# %%
import matplotlib.pyplot as plt
import numpy as np
import scienceplots  # noqa: F401

plt.style.use("science")

# %%
mclmc = np.load("../data/mclmc_dc.npz")
rw = np.load("../data/rw_dc.npz")
vi = np.load("../data/vi_dc.npz")

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(20, 5))

hist_kwargs = dict(
    alpha=0.8,
    bins=50,
    density=True,
)

ax1.hist(mclmc["alpha"][2000:], label="MCLMC", **hist_kwargs)
ax1.hist(rw["alpha"][10_000:], label="RW", **hist_kwargs)
ax1.hist(vi["alpha"], label="VI", **hist_kwargs)

ax2.hist(mclmc["kappa0"][2000:], **hist_kwargs)
ax2.hist(rw["kappa0"][10_000:], **hist_kwargs)
ax2.hist(vi["kappa0"], **hist_kwargs)

ax3.hist(mclmc["eps0"][2000:], **hist_kwargs)
ax3.hist(rw["eps0"][10_000:], **hist_kwargs)
ax3.hist(vi["eps0"], **hist_kwargs)

ax1.set_title(r"Distribution of $\alpha$")
ax2.set_title(r"Distribution of $\kappa_0$")
ax3.set_title(r"Distribution of $\epsilon_0$")

ax1.set_xlabel(r"$\alpha$")
ax2.set_xlabel(r"$\kappa_0$")

ax1.set_ylabel("Probability density")
ax2.set_ylabel("Probability density")
ax3.set_ylabel("Probability density")


handles, labels = ax1.get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc="lower center",
    ncol=3,
    frameon=False,
)

fig.suptitle(
    "Posterior distributions obtained using Linear Sweep DC Voltammetry",
    fontsize=18,
    y=0.98,
)

plt.show()

# %%
mclmc = np.load("../data/mclmc_ac.npz")
rw = np.load("../data/rw_ac.npz")
vi = np.load("../data/vi_ac.npz")

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(20, 5))

hist_kwargs = dict(
    alpha=0.8,
    bins=50,
    density=True,
)

ax1.hist(mclmc["alpha"][2000:], label="MCLMC", **hist_kwargs)
ax1.hist(rw["alpha"][10_000:], label="RW", **hist_kwargs)
ax1.hist(vi["alpha"], label="VI", **hist_kwargs)

ax2.hist(mclmc["kappa0"][2000:], **hist_kwargs)
ax2.hist(rw["kappa0"][10_000:], **hist_kwargs)
ax2.hist(vi["kappa0"], **hist_kwargs)

ax3.hist(mclmc["eps0"][2000:], **hist_kwargs)
ax3.hist(rw["eps0"][10_000:], **hist_kwargs)
ax3.hist(vi["eps0"], **hist_kwargs)

ax1.set_title(r"Distribution of $\alpha$")
ax2.set_title(r"Distribution of $\kappa_0$")
ax3.set_title(r"Distribution of $\epsilon_0$")

ax1.set_xlabel(r"$\alpha$")
ax2.set_xlabel(r"$\kappa_0$")

ax1.set_ylabel("Probability density")
ax2.set_ylabel("Probability density")
ax3.set_ylabel("Probability density")


handles, labels = ax1.get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc="lower center",
    ncol=3,
    frameon=False,
)

fig.suptitle(
    "Posterior distributions obtained using Linear Sweep AC Voltammetry",
    fontsize=18,
    y=0.98,
)

plt.show()

# %%
dc = np.load("../data/rw_dc.npz")
ac = np.load("../data/rw_ac.npz")

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15, 5))

hist_kwargs = dict(
    alpha=0.8,
    bins=50,
    density=True,
)

ax1.hist(dc["alpha"][10_000:], label="DC", **hist_kwargs)
ax1.hist(ac["alpha"][10_000:], label="AC", **hist_kwargs)

ax2.hist(dc["kappa0"][10_000:], **hist_kwargs)
ax2.hist(ac["kappa0"][10_000:], **hist_kwargs)

ax3.hist(dc["eps0"][10_000:], **hist_kwargs)
ax3.hist(ac["eps0"][10_000:], **hist_kwargs)

ax1.set_title(r"Distribution of $\alpha$")
ax2.set_title(r"Distribution of $\kappa_0$")
ax3.set_title(r"Distribution of $\epsilon_0$")

ax1.set_xlabel(r"$\alpha$")
ax2.set_xlabel(r"$\kappa_0$")
ax3.set_xlabel(r"$\epsilon_0$")

ax1.set_ylabel("Probability density")
ax2.set_ylabel("Probability density")
ax3.set_ylabel("Probability density")


handles, labels = ax1.get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc="lower center",
    ncol=2,
    frameon=False,
)

fig.suptitle(
    "Posterior distributions obtained using Metropolis-Hasting",
    fontsize=18,
    y=0.98,
)

plt.show()

# %%
dc = np.load("../data/mclmc_dc.npz")
ac = np.load("../data/mclmc_ac.npz")

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15, 5))

hist_kwargs = dict(
    alpha=0.8,
    bins=50,
    density=True,
)

ax1.hist(dc["alpha"][2000:], label="DC", **hist_kwargs)
ax1.hist(ac["alpha"][2000:], label="AC", **hist_kwargs)

ax2.hist(dc["kappa0"][2000:], **hist_kwargs)
ax2.hist(ac["kappa0"][2000:], **hist_kwargs)

ax3.hist(dc["eps0"][2000:], **hist_kwargs)
ax3.hist(ac["eps0"][2000:], **hist_kwargs)

ax1.set_title(r"Distribution of $\alpha$")
ax2.set_title(r"Distribution of $\kappa_0$")
ax3.set_title(r"Distribution of $\epsilon_0$")

ax1.set_xlabel(r"$\alpha$")
ax2.set_xlabel(r"$\kappa_0$")
ax3.set_xlabel(r"$\epsilon_0$")

ax1.set_ylabel("Probability density")
ax2.set_ylabel("Probability density")
ax3.set_ylabel("Probability density")


handles, labels = ax1.get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc="lower center",
    ncol=2,
    frameon=False,
)

fig.suptitle(
    "Posterior distributions obtained using MCLMC",
    fontsize=18,
    y=0.98,
)

plt.show()
